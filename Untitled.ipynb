# %% [markdown]
# # Challenges of the day:
#
# # - Plot a bar graph to show the rating distribution. Means that, a bar chart shows how many business are rated as 1 star, 1.5 stars and so on
#
# # - Find a way to find the unique categories, and plot a bar chart to show 20 most popular categories
#
# # - Plot a bar chart to show top 20 cities that have the most number businesses
#
# # - Select 1 city of your choice, then:
#
# # -filter out all businesses in that city
#
# # -find the 5 most popular business categories.
#
# # -plot a bar chart to show the amount of checkins by hours of each business in the top 5 above ( meaning, x-axis is the hours, and y-axis is the amount of checkins)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
business_df =pd.read_csv('yelp_business.csv')

# %%
business_df.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
categories_list2=[x for x in business_df.categories.values]

# %%
categories_list2
# Out:
# ['Dentists;General Dentistry;Health & Medical;Oral Surgeons;Cosmetic Dentists;Orthodontists',
#  "Hair Stylists;Hair Salons;Men's Hair Salons;Blow Dry/Out Services;Hair Extensions;Beauty & Spas",
#  'Departments of Motor Vehicles;Public Services & Government',
#  'Sporting Goods;Shopping',
#  'American (New);Nightlife;Bars;Sandwiches;American (Traditional);Burgers;Restaurants',
#  'Italian;Restaurants',
#  'Real Estate Services;Real Estate;Home Services;Property Management',
#  'Shopping;Sporting Goods',
#  'Coffee & Tea;Ice Cream & Frozen Yogurt;Food',
#  'Automotive;Auto Detailing',
#  'Breakfast & Brunch;Gluten-Free;Coffee & Tea;Food;Restaurants;Sandwiches',
#  'Local Services;Self Storage',
#  'Bakeries;Bagels;Food',
#  'General Dentistry;Dentists;Endodontists;Cosmetic Dentists;Health & Medical;Orthodontists',
#  'Restaurants;American (Traditional)',
#  'Italian;French;Restaurants',
#  'Beauty & Spas;Nail Salons',
#  'Tires;Oil Change Stations;Auto Repair;Automotive',
#  'Barbers;Beauty & Spas',
#  'French;Food;Bakeries;Restaurants',
#  'Food;Coffee & Tea',
#  'Shopping;Books;Mags;Music & Video;Music & DVDs',
#  'Public Services & Government',
#  'Fitness & Instruction;Sports Clubs;Gyms;Trainers;Active Life',
#  'Bars;Sports Bars;Nightlife',
#  'Tiki Bars;Nightlife;Mexican;Restaurants;Bars',
#  'Shopping;Jewelry;Watch Repair;Local Services',
#  'Coffee & Tea;Food;Tea Rooms',
#  'Soup;Salad;Sandwiches;Restaurants',
#  'Food;American (Traditional);Coffee & Tea;Restaurants',
#  'Restaurants;Breakfast & Brunch',
#  'Oil Change Stations;Smog Check Stations;Automotive;Auto Repair',
#  'Arts & Entertainment;Festivals;Restaurants;French;Gastropubs',
#  'Coffee & Tea;Restaurants;Food;Mediterranean;Tea Rooms',
#  'Nail Salons;Beauty & Spas',
#  'Nightlife;Pubs;Bars',
#  'Home Services;Contractors;Pool & Hot Tub Service;Pool Cleaners',
#  'Hair Salons;Blow Dry/Out Services;Hair Stylists;Beauty & Spas;Hair Extensions',
#  'Home & Garden;Furniture Stores;Shopping',
#  'Event Planning & Services;Caterers',
#  'Nightlife;Izakaya;Comfort Food;Cocktail Bars;Asian Fusion;Bars;Japanese;Restaurants;Gastropubs;Tapas/Small Plates',
#  'Home Services;Lighting Fixtures & Equipment;Local Services;Electricians;TV Mounting',
#  'Desserts;Ice Cream & Frozen Yogurt;Food',
#  'Shopping;Guns & Ammo',
#  'Restaurants;Italian;Seafood',
#  'Fast Food;Burgers;Restaurants',
#  'Burgers;Restaurants',
#  'Tanning;Day Spas;Spray Tanning;Beauty & Spas;Hair Salons',
#  'Nurseries & Gardening;Home & Garden;Shopping',
#  'Arts & Entertainment;Performing Arts',
#  'Italian;Restaurants',
#  'Hotels & Travel;Car Rental',
#  'Nightlife;Bars;Barbeque;Sports Bars;American (New);Restaurants',
#  'Fast Food;Restaurants;Sandwiches',
#  'Arcades;Arts & Entertainment;Gastropubs;Restaurants;American (New)',
#  'Restaurants;Mexican',
#  'Active Life;Fitness & Instruction;Gyms',
#  'Restaurants;Chinese',
#  'Eyelash Service;Beauty & Spas',
#  'Automotive;Auto Repair',
#  'Education;Performing Arts;Specialty Schools;Art Schools;Arts & Entertainment',
#  'Food;Coffee & Tea;Desserts',
#  'Automotive;Body Shops;Auto Glass Services',
#  'Home Cleaning;Home Services;Window Washing',
#  'Cafes;Restaurants',
#  'Health & Medical;General Dentistry;Dentists',
#  'Office Cleaning;Carpet Cleaning;Professional Services;Home Cleaning;Home Services;Local Services',
#  'Home Services;Television Service Providers;Home Automation;Home Theatre Installation;Professional Services',
#  'Breakfast & Brunch;Diners;Restaurants;Cafes;British',
#  'Bakeries;Food',
#  'Doctors;Health & Medical',
#  'Orthopedists;Health & Medical;Doctors',
#  'Restaurants;Burgers;Fast Food',
#  'Sporting Goods;Shopping',
#  "Men's Clothing;Women's Clothing;Fashion;Shopping",
#  'Restaurants;Sandwiches;Coffee & Tea;Food',
#  'Breakfast & Brunch;Bagels;Restaurants;Bakeries;Sandwiches;Food',
#  'Hotels;Event Planning & Services;Hotels & Travel',
#  'Shopping;Public Services & Government;Departments of Motor Vehicles',
#  'Health & Medical;Chiropractors',
#  'Restaurants;Pizza',
#  'American (Traditional);Nightlife;Dive Bars;Restaurants;Bars',
#  'Performing Arts;Arts & Entertainment',
#  'Beauty & Spas;Piercing;Tattoo',
#  'Watch Repair;Jewelry Repair;Shopping;Local Services;Jewelry',
#  'Event Planning & Services;Nightlife;Lounges;Venues & Event Spaces;Bars',
#  'Imported Food;Specialty Food;Thai;Ethnic Food;Food;Restaurants',
#  'Florists;Wholesale Stores;Shopping;Flowers & Gifts',
#  "Marketing;Men's Clothing;Restaurants;Graphic Design;Women's Clothing;Screen Printing;Advertising;Pizza;Shopping;Web Design;Fashion;Local Services;Screen Printing/T-Shirt Printing;Professional Services",
#  'Venues & Event Spaces;Event Planning & Services',
#  'Restaurants;Italian',
#  'Italian;Restaurants',
#  'Real Estate Agents;Home Services;Real Estate',
#  'Optometrists;Doctors;Internal Medicine;Health & Medical',
#  'Ice Cream & Frozen Yogurt;Food',
#  'Religious Organizations',
#  'Restaurants;Chinese;Food Court',
#  'Restaurants;Cuban',
#  'Nightlife;Adult Entertainment;Strip Clubs',
#  'Education;Dance Schools;Arts & Entertainment;Fitness & Instruction;Specialty Schools;Active Life;Dance Studios;Performing Arts',
#  'Pets;Veterinarians',
#  'Restaurants;Gluten-Free;Indian;Seafood',
#  'Auto Parts & Supplies;Auto Repair;Tires;Automotive',
#  'Pizza;Food;Internet Cafes;Restaurants;Caribbean',
#  'Breakfast & Brunch;Food;Coffee & Tea;Canadian (New);Restaurants',
#  'Weight Loss Centers;Physical Therapy;Health & Medical',
#  'Pet Groomers;Pet Sitting;Pets;Pet Services;Pet Training',
#  'American (Traditional);Restaurants;Seafood',
#  'Food;Donuts',
#  'Kitchen & Bath;Countertop Installation;Home Services;Tiling;Contractors;Shopping;Home & Garden',
#  'Local Services;Appliances & Repair',
#  'Veterinarians;Pets',
#  'Contractors;Arts & Crafts;Shopping;Flooring;Home Services',
#  'Indian;Restaurants;Fast Food',
#  'Smog Check Stations;Automotive;Auto Repair;Body Shops',
#  'Art Galleries;Arts & Entertainment;Head Shops;Tobacco Shops;Shopping',
#  'Italian;Chicken Wings;Fast Food;Restaurants;Pizza',
#  'Food;Restaurants;Tacos;Food Trucks;Mexican',
#  'Pizza;Restaurants',
#  'Massage;Massage Therapy;Health & Medical;Skin Care;Day Spas;Beauty & Spas',
#  'Vegan;American (New);Restaurants;Sandwiches;Salad;Wraps;Food',
#  'Automotive;Motorcycle Repair',
#  'Restaurants;Fast Food;Burgers',
#  'Health & Medical;Counseling & Mental Health',
#  "Department Stores;Home Decor;Shopping;Fashion;Women's Clothing;Discount Store;Home & Garden;Men's Clothing",
#  'Wedding Planning;Venues & Event Spaces;Shopping;Bridal;Event Planning & Services',
#  'Buffets;Restaurants;Sushi Bars;Chinese',
#  'Cafes;Nightlife;Wine Bars;Bars;Restaurants',
#  'Breakfast & Brunch;Food;Coffee & Tea;Donuts;Restaurants',
#  'Home Services;Air Duct Cleaning;Local Services;Heating & Air Conditioning/HVAC',
#  'Food;Delis;Fast Food;Sandwiches;Restaurants',
#  'Automotive;Tires;Auto Repair;Auto Parts & Supplies;Oil Change Stations',
#  'Burgers;Restaurants',
#  'Restaurants;Cafes;American (New);Bars;Nightlife;Wine Bars',
#  'Shopping;Drugstores',
#  'Burgers;Fast Food;Restaurants',
#  'Optometrists;Health & Medical;Eyewear & Opticians;Shopping',
#  'Tobacco Shops;Hobby Shops;Shopping',
#  'Home Services;Grout Services;Carpet Cleaning;Damage Restoration;Home Cleaning;Local Services',
#  'Party & Event Planning;Wedding Planning;Event Planning & Services',
#  'Office Equipment;Shopping',
#  'Convenience Stores;Desserts;Food Delivery Services;Food;Grocery',
#  'Restaurants;Food;Vietnamese',
#  'Arcades;Arts & Entertainment;Party & Event Planning;Escape Games;Event Planning & Services;Active Life',
#  'Beauty & Spas;Nail Salons',
#  'Sandwiches;Restaurants;Fast Food',
#  'Restaurants;Coffee & Tea;Cafes;German;Food',
#  'Comedy Clubs;Nightlife;Shopping',
#  'Food;Bakeries;Donuts',
#  'Hotels & Travel;Event Planning & Services;Hotels',
#  'Chocolatiers & Shops;Desserts;Specialty Food;Food',
#  'Health & Medical;Active Life;Weight Loss Centers;Fitness & Instruction;Trainers;Nutritionists;Gyms',
#  'Pest Control;Local Services',
#  'Donuts;Food',
#  'Restaurants;Sushi Bars;Japanese;Asian Fusion',
#  'Food;Coffee & Tea;Massage;Beauty & Spas',
#  'Restaurants;Creperies',
#  'Mobile Phones;IT Services & Computer Repair;Shopping;Electronics Repair;Mobile Phone Repair;Local Services',
#  'Pizza;Restaurants',
#  'Arts & Entertainment;Performing Arts',
#  'Plumbing;Home Services',
#  'Restaurants;Chinese',
#  'Hair Salons;Beauty & Spas;Nail Salons',
#  'Seafood Markets;Food;Specialty Food',
#  'Health Markets;Food;Beauty & Spas;Specialty Food;Shopping;Cosmetics & Beauty Supply',
#  'Tobacco Shops;Shopping;Vape Shops',
#  'Musical Instruments & Teachers;Shopping',
#  'Restaurants;Sandwiches;Delicatessen;Asian Fusion;Food;Cafes',
#  'Septic Services;Home Services;Plumbing;Local Services',
#  'Blow Dry/Out Services;Hair Salons;Barbers;Hair Stylists;Beauty & Spas',
#  'Food;Local Flavor;Canadian (New);Sugar Shacks;Restaurants;American (Traditional)',
#  'Eyewear & Opticians;Health & Medical;Shopping;Optometrists',
#  'Restaurants;Thai;Vietnamese;Chinese',
#  'Hotels & Travel;Transportation;Public Transportation',
#  'Electricians;Home Services;Heating & Air Conditioning/HVAC;Plumbing',
#  'Hiking;Active Life',
#  'Shopping;Fashion;Shoe Stores',
#  'Restaurants;American (Traditional)',
#  'Italian;Pizza;Restaurants;Salad',
#  'Mexican;Tex-Mex;Restaurants;Fast Food',
#  'Pizza;Restaurants;Fast Food',
#  'Burgers;Restaurants',
#  'Hotels;Restaurants;Event Planning & Services;American (New);Hotels & Travel',
#  'Shopping;Adult',
#  'Italian;Restaurants',
#  'Auto Parts & Supplies;Automotive;Auto Repair',
#  'Tiling;Carpet Cleaning;Home Services;Refinishing Services;Local Services',
#  "Fashion;Women's Clothing;Accessories;Shopping",
#  "Accessories;Women's Clothing;Fashion;Shopping",
#  'Wedding Planning;Fashion;Formal Wear;Event Planning & Services;Bridal;Party & Event Planning;Shopping',
#  'Restaurants;Greek;Salad;Mediterranean',
#  'Nightlife;Japanese;Music Venues;Ramen;Arts & Entertainment;Restaurants;Bars',
#  'Real Estate Services;Real Estate;Home Services',
#  'Automotive;Gas Stations',
#  'Bakeries;Coffee & Tea;Bubble Tea;Food',
#  'Active Life;Parks;Playgrounds',
#  'Sewing & Alterations;Local Services;Shoe Repair',
#  'Automotive;Auto Detailing;Mobile Dent Repair;Auto Upholstery;Auto Glass Services',
#  'Day Spas;Hair Salons;Beauty & Spas',
#  'Sewing & Alterations;Local Services',
#  'Massage;Nail Salons;Skin Care;Day Spas;Beauty & Spas',
#  'Active Life;Sports Clubs;Gyms;Fitness & Instruction;Trainers',
#  'Motorcycle Repair;Automotive;Motorcycle Dealers',
#  'Photography Stores & Services;Shopping;Beauty & Spas;Cosmetics & Beauty Supply;Drugstores',
#  'Automotive;Auto Repair;Body Shops',
#  'Yoga;Active Life;Fitness & Instruction',
#  'Tex-Mex;Mexican;Restaurants;Fast Food',
#  'Shopping;Health & Medical;Eyewear & Opticians;Optometrists',
#  'Local Services;Home Services;Plumbing;Septic Services;Water Heater Installation/Repair',
#  'Pets;Veterinarians;Pet Services;Pet Groomers;Pet Sitting',
#  'Juice Bars & Smoothies;Food',
#  'Churches;Religious Organizations',
#  'Home & Garden;Active Life;Home Decor;Shopping;Discount Store;Furniture Stores;Swimming Pools',
#  'Active Life;Boot Camps;Trainers;Fitness & Instruction;Gyms',
#  'Active Life;Parks;Local Flavor',
#  'Food Court;Restaurants;Barbeque',
#  'Music Venues;Lounges;Dive Bars;Bars;Nightlife;Piano Bars;Arts & Entertainment',
#  'Home Services;Shopping;Home Decor;Shades & Blinds;Interior Design;Building Supplies;Home & Garden',
#  'Canadian (New);Restaurants;Breakfast & Brunch',
#  'Pool & Hot Tub Service;Home Services;Landscape Architects;Active Life;Contractors;Swimming Pools;Landscaping',
#  'Italian;Restaurants;Sandwiches;Hot Dogs',
#  'Transportation;Event Planning & Services;Airlines;Hotels & Travel;Airport Shuttles;Limos;Party Bus Rentals;Public Transportation',
#  "Fashion;Men's Clothing;Shopping;Plus Size Fashion;Formal Wear",
#  "Shopping;Men's Clothing;Shoe Stores;Fashion;Women's Clothing",
#  'Mortgage Brokers;Financial Services;Mortgage Lenders;Real Estate;Home Services',
#  'Hair Removal;Beauty & Spas;Waxing;Nail Salons',
#  'Auto Repair;Gas Stations;Automotive',
#  'Arts & Entertainment;Yelp Events;Festivals;Local Flavor',
#  'Restaurants;Pizza',
#  'Shopping;Grocery;Florists;Flowers & Gifts;Bakeries;Convenience Stores;Food',
#  'Active Life;Sporting Goods;Karate;Education;Shopping;Martial Arts;Specialty Schools;Trainers;Fitness & Instruction',
#  'Pet Services;Pet Sitting;Dog Walkers;Pets',
#  'Fashion;Shoe Stores;Shopping',
#  'Chicken Wings;Restaurants;Fast Food',
#  "Shopping;Sporting Goods;Women's Clothing;Men's Clothing;Sports Wear;Fashion",
#  'Cosmetic Dentists;Dentists;Orthodontists;Health & Medical;General Dentistry',
#  'Jewelry;Arts & Crafts;Shopping',
#  'Pets;Veterinarians;Pet Services',
#  'Automotive;Auto Parts & Supplies',
#  'Food;Donuts;Coffee & Tea',
#  'Shopping;Sporting Goods',
#  'Restaurants;Sandwiches;Delis',
#  'Flooring;Carpeting;Carpet Installation;Home Services',
#  'Italian;Restaurants;Pizza',
#  'Education;Health & Medical;Beauty & Spas;Massage;Physical Therapy;Massage Therapy',
#  'Beauty & Spas;Hair Salons',
#  'Massage;Beauty & Spas',
#  'Real Estate Services;Real Estate;Home Services;Property Management;Real Estate Agents',
#  'Chinese;Restaurants;Dim Sum',
#  'Restaurants;Fast Food',
#  'Mexican;Restaurants;Nightlife;Bars',
#  'Fast Food;Restaurants;Chinese',
#  'Food;Caterers;Restaurants;Fast Food;French;Event Planning & Services;Food Delivery Services',
#  'Sushi Bars;Restaurants;Japanese;Asian Fusion;Vietnamese',
#  'Fast Food;Restaurants;Burgers;Breakfast & Brunch;American (New)',
#  'Motorcycle Dealers;Automotive',
#  'Food;Ice Cream & Frozen Yogurt',
#  'Auto Parts & Supplies;Automotive',
#  'Fruits & Veggies;Shopping;Specialty Food;Flowers & Gifts;Food;Florists',
#  'Preschools;Child Care & Day Care;Local Services;Education;Elementary Schools',
#  'Home Services;Real Estate',
#  'Vietnamese;Restaurants',
#  'Arts & Entertainment;American (Traditional);Sushi Bars;Nightlife;Restaurants;Music Venues',
#  'Fashion;Clothing Rental;Uniforms;Building Supplies;Home Services;Shopping',
#  'Beer;Wine & Spirits;Food',
#  'Restaurants;Asian Fusion',
#  'Shopping;Home & Garden;Furniture Stores',
#  'Music Venues;Nightlife;Arts & Entertainment',
#  'Italian;Pizza;Chicken Wings;Restaurants',
#  'Flowers & Gifts;Shopping;Florists',
#  'Bars;Wine Bars;Nightlife',
#  'Restaurants;Noodles;Vietnamese',
#  'Restaurants;Italian',
#  'Restaurants;Italian',
#  'Seafood;Italian;Pizza;Restaurants',
#  'Hair Extensions;Nail Salons;Makeup Artists;Hair Salons;Permanent Makeup;Beauty & Spas',
#  'Pubs;Nightlife;Bars',
#  'Food;Delis;Bakeries;Restaurants',
#  'Food;Specialty Food;Health Markets',
#  'Automotive;Gas Stations',
#  'Notaries;Printing Services;Shipping Centers;Local Services',
#  'Arts & Entertainment;Health & Medical;Supernatural Readings',
#  'Burgers;Restaurants',
#  'General Dentistry;Dentists;Health & Medical',
#  'Home Services;Painters',
#  'Stadiums & Arenas;Arts & Entertainment;Professional Sports Teams',
#  'Heating & Air Conditioning/HVAC;Plumbing;Home Services',
#  'Financial Services;Accountants;Tax Services;Professional Services',
#  'Event Planning & Services;American (New);Sandwiches;Salad;Caterers;Restaurants',
#  'Local Flavor;Festivals;Arts & Entertainment',
#  'Buffets;Restaurants;Indian',
#  'Beauty & Spas;Nail Salons',
#  'Yoga;Health & Medical;Active Life;Fitness & Instruction;Physical Therapy;Trainers',
#  'Restaurants;Japanese;Sushi Bars',
#  'Doctors;Midwives;Urgent Care;Health & Medical;Medical Centers',
#  'Auto Repair;Oil Change Stations;Tires;Automotive',
#  'Performing Arts;Arts & Entertainment',
#  'Martial Arts;Fitness & Instruction;Boxing;Gyms;Active Life;Trainers',
#  'Amusement Parks;Parks;Active Life',
#  'Medical Centers;Cannabis Clinics;Pharmacy;Health & Medical;Walk-in Clinics',
#  'Nightlife',
#  'Bars;Nightlife;Cocktail Bars',
#  'Dance Clubs;Arts & Entertainment;Music Venues;Nightlife;Lounges;Bars',
#  'Karaoke;Bars;Mexican;Restaurants;Nightlife;Dance Clubs',
#  'Religious Organizations;Churches',
#  'Coffee & Tea;Food',
#  'Local Services;Dry Cleaning & Laundry;Laundry Services',
#  'American (Traditional);Breakfast & Brunch;Salad;Burgers;Restaurants',
#  'Professional Services',
#  'Italian;Restaurants',
#  'Pizza;Italian;Chicken Wings;Restaurants',
#  'Body Shops;Automotive',
#  'Restaurants;Chinese',
#  'Restaurants;Mexican',
#  'Gymnastics;Dance Schools;Performing Arts;Arts & Entertainment;Martial Arts;Summer Camps;Fitness & Instruction;Gyms;Specialty Schools;Active Life;Education',
#  'Movers;Home Services',
#  'Real Estate;Home Services;Apartments',
#  'Food;Ice Cream & Frozen Yogurt',
#  'Restaurants;American (Traditional)',
#  'Health & Medical;Pediatric Dentists;Orthodontists;General Dentistry;Cosmetic Dentists;Dentists',
#  'Drugstores;Food;Beauty & Spas;Convenience Stores;Cosmetics & Beauty Supply;Shopping',
#  'Advertising;Graphic Design;Local Services;Professional Services;Screen Printing/T-Shirt Printing;Screen Printing',
#  'American (Traditional);Burgers;Restaurants',
#  'Beauty & Spas;Tanning',
#  "Women's Clothing;Men's Clothing;Shopping;Fashion;Accessories;Sports Wear;Sporting Goods",
#  'Automotive;Auto Parts & Supplies',
#  'Bars;Nightlife;Dive Bars',
#  'Chinese;Restaurants;Vietnamese;Asian Fusion',
#  'Midwives;Health & Medical',
#  'Restaurants;Italian;Chicken Wings;Pizza',
#  'Restaurants;Thai',
#  'Food;Arts & Entertainment;Wineries;Beer;Wine & Spirits',
#  'Beer;Wine & Spirits;American (New);Restaurants;Nightlife;Food;Bars;Belgian;Sandwiches;Pubs',
#  'Education;Elementary Schools',
#  'Drugstores;Convenience Stores;Food;Shopping',
#  'Greek;Vegetarian;Sandwiches;Mediterranean;Restaurants',
#  'Medical Spas;Beauty & Spas;Hair Removal;Nail Salons;Health & Medical;Day Spas;Hair Salons',
#  'Na',
#  'Arts & Entertainment;Festivals',
#  'Restaurants;Mexican',
#  'Festivals;Arts & Entertainment',
#  'German;International;Food;Restaurants;French;Specialty Food;Modern European',
#  'Restaurants;Chinese',
#  'Automotive;Auto Repair',
#  'Restaurants',
#  'Appliances & Repair;Local Services;Home Services;Heating & Air Conditioning/HVAC',
#  'Wedding Planning;Beauty & Spas;Eyelash Service;Makeup Artists;Nail Salons;Event Planning & Services',
#  'Landscaping;Home Services',
#  'Home Services;Window Washing;Professional Services;Contractors;Office Cleaning;Home Cleaning;Pressure Washers',
#  'Shopping;Mobile Phones',
#  'Diagnostic Imaging;Diagnostic Services;Health & Medical;Doctors',
#  'Restaurants;Asian Fusion;Thai',
#  'Bakeries;Food;Desserts',
#  'Sports Wear;Sporting Goods;Shopping;Bikes;Fashion',
#  'Real Estate;Apartments;Home Services',
#  'Plumbing;Home Services;Utilities',
#  'Food;Coffee & Tea',
#  'Restaurants;Breakfast & Brunch',
#  'Grocery;Food',
#  'Restaurants;Fast Food;Mexican',
#  'Restaurants;Vietnamese',
#  'Photographers;Event Planning & Services;Session Photography;Professional Services;Video/Film Production',
#  'Massage Therapy;Massage;Fitness & Instruction;Beauty & Spas;Day Spas;Health & Medical;Active Life;Yoga',
#  'Food;Food Trucks;Specialty Food;Candy Stores;Ice Cream & Frozen Yogurt',
#  'American (Traditional);Restaurants;Sandwiches;Steakhouses;American (New);Fast Food',
#  'Shopping;Health & Medical;Eyewear & Opticians;Optometrists',
#  'Restaurants;Thai',
#  'Solar Installation;Home Services',
#  'Active Life;Gymnastics',
#  'Skin Care;Permanent Makeup;Health & Medical;Reflexology;Beauty & Spas',
#  'Food;Coffee & Tea;Bakeries',
#  'Pizza;Restaurants',
#  'IT Services & Computer Repair;Local Services;Computers;Shopping;Electronics;Home & Garden;Furniture Stores',
#  'Coffee & Tea;Food',
#  'Barbeque;Sports Bars;Restaurants;Nightlife;Bars;Chicken Wings',
#  'Shopping;Home Decor;Discount Store;Home & Garden',
#  'Drugstores;Shopping',
#  'Restaurants;Breakfast & Brunch',
#  'Fast Food;Restaurants;Burgers',
#  'Dance Clubs;Nightlife;Restaurants;Barbeque;American (Traditional)',
#  'Restaurants;Food;Sandwiches;Coffee & Tea;Delis',
#  'Shopping;Shopping Centers',
#  'Restaurants;Japanese;Sushi Bars',
#  'Car Stereo Installation;Automotive',
#  'Grocery;Food',
#  'Restaurants;Barbeque',
#  'Movers;Home Services',
#  'Home Services;Window Washing;Local Services;Pest Control',
#  'Bubble Tea;Restaurants;Food;Vietnamese',
#  'Books;Mags;Music & Video;Shopping;Music & DVDs;Videos & Video Game Rental',
#  'Automotive;Parking',
#  'Real Estate;Apartments;Home Services',
#  'Tex-Mex;Fast Food;Restaurants;Mexican',
#  'Paintball;Active Life;Airsoft;Parks',
#  'American (New);American (Traditional);Restaurants;Breakfast & Brunch;Diners',
#  'Restaurants;Pizza',
#  'Trainers;Active Life;Health & Medical;Fitness & Instruction;Sports Clubs;Gyms',
#  'Restaurants;Cantonese;Chinese',
#  "Sporting Goods;Books;Mags;Music & Video;Fashion;Used Bookstore;Sports Wear;Shopping;Men's Clothing;Souvenir Shops;Bookstores",
#  'Restaurants;Chinese',
#  'Ice Cream & Frozen Yogurt;Food',
#  'Optometrists;Health & Medical',
#  'Restaurants;Asian Fusion',
#  'Automotive;Food;Grocery;Beer;Wine & Spirits;Gas Stations',
#  'Chicken Wings;Fast Food;Restaurants',
#  'Pet Groomers;Pet Sitting;Pets;Pet Services',
#  'Car Rental;Hotels & Travel',
#  'Muay Thai;Kickboxing;Trainers;Gyms;Martial Arts;Fitness & Instruction;Active Life',
#  'Nightlife;Restaurants;Steakhouses;Wine Bars;Bars;Seafood',
#  'Burgers;Restaurants',
#  "Women's Clothing;Shopping;Fashion",
#  'Food;Grocery',
#  'Food;Convenience Stores',
#  'Shopping;Flowers & Gifts;Gift Shops',
#  'Restaurants;Chinese',
#  'Personal Injury Law;Professional Services;Lawyers',
#  'Restaurants;Asian Fusion;Korean',
#  'Medical Centers;Health & Medical',
#  'Shopping;Home & Garden;Self Storage;Home Decor;Local Services',
#  'Nail Salons;Beauty & Spas',
#  'Burgers;Restaurants',
#  'Active Life;Playgrounds;Parks',
#  'Arts & Entertainment',
#  'Tobacco Shops;Convenience Stores;Food;Shopping',
#  'Employment Agencies;Career Counseling;Professional Services',
#  'Art Galleries;Shopping;Arts & Entertainment;Museums',
#  'Shopping;Fashion;Department Stores',
#  'International Grocery;Shopping;Food',
#  'Breakfast & Brunch;Restaurants',
#  'Dance Clubs;Bars;Nightlife',
#  'Fast Food;Chicken Wings;Southern;Restaurants',
#  'Restaurants;Italian',
#  'Restaurants;Hungarian',
#  'Restaurants;American (Traditional);Food;Coffee & Tea;Salad;Breakfast & Brunch',
#  'Apartments;Home Services;Real Estate',
#  'Greek;Restaurants;American (New)',
#  'Hot Tub & Pool;Shopping;Home & Garden',
#  'Automotive;Tires',
#  'Marketing;Professional Services',
#  'Automotive;Auto Parts & Supplies;Body Shops;Auto Repair',
#  'Chinese;Restaurants',
#  'Hotels & Travel;Hotels;Event Planning & Services',
#  'Home Services;Painters',
#  'Windows Installation;Home Services;Glass & Mirrors;Auto Glass Services;Windshield Installation & Repair;Automotive',
#  'Beauty & Spas;Barbers',
#  'Local Services;Carpet Cleaning',
#  'Pubs;Whiskey Bars;Nightlife;Breakfast & Brunch;Restaurants;Bars',
#  'Grocery;Food;Shopping',
#  'Mobile Phones;Food;Discount Store;Drugstores;Shopping;Grocery;Fashion;Department Stores',
#  'Auto Detailing;Automotive;Auto Customization;Car Wash',
#  'Artificial Turf;Home Services',
#  'Southern;Mexican;Restaurants;Nightlife;Bars',
#  'Shades & Blinds;Window Washing;Pressure Washers;Home Services',
#  'Burgers;Bars;Restaurants;Pizza;Nightlife;Pubs',
#  'Food Delivery Services;Caterers;Event Planning & Services;Food',
#  'Automotive;Body Shops;Auto Detailing;Auto Repair',
#  'Automotive;Auto Detailing',
#  'Food;Food Trucks',
#  'Shopping;Utilities;Home Services;Mobile Phones',
#  'Arts & Crafts;Fashion;Shopping;Antiques;Used;Vintage & Consignment',
#  'Indian;Restaurants',
#  'Fast Food;Restaurants;Ice Cream & Frozen Yogurt;Food',
#  'Shopping;Discount Store',
#  'Bars;Lounges;Nightlife',
#  'Antiques;Shopping;Toy Stores',
#  'Health & Medical;Eyewear & Opticians;Shopping;Optometrists',
#  'Fitness & Instruction;Yoga;Active Life',
#  'Beauty & Spas;Nail Salons',
#  'Transportation;Public Transportation;Hotels & Travel',
#  'Shopping;Home Services;Furniture Stores;Thrift Stores;Building Supplies;Local Services;Home & Garden;Community Service/Non-Profit',
#  'Tanning;Beauty & Spas;Hair Salons;Makeup Artists',
#  'Restaurants;Mexican;Latin American',
#  'Mexican;Restaurants',
#  'Pakistani;Restaurants;Indian;Seafood;Halal',
#  'Restaurants;Italian',
#  'Salad;Restaurants;Vegetarian;Gluten-Free',
#  'Beauty & Spas;Hair Salons',
#  'Gyms;Sports Clubs;Active Life;Recreation Centers;Fitness & Instruction;Badminton',
#  'Restaurants;Mexican',
#  'Home Services;Windows Installation;Door Sales/Installation',
#  'Local Services;Education;Preschools;Child Care & Day Care;Elementary Schools',
#  'Restaurants;Chicken Shop',
#  'Hair Extensions;Hair Stylists;Hair Salons;Beauty & Spas',
#  'Hair Salons;Day Spas;Beauty & Spas',
#  'Sandwiches;Food;Restaurants;Coffee & Tea;Breakfast & Brunch',
#  'Party Equipment Rentals;Event Planning & Services',
#  'Active Life;Yoga;Fitness & Instruction',
#  'Health & Medical;Optometrists',
#  'Health & Medical;Orthopedists;Doctors',
#  'Auto Repair;Car Dealers;Auto Parts & Supplies;Automotive',
#  'Fast Food;Restaurants',
#  'Electronics;Appliances;Home & Garden;Appliances & Repair;Shopping;Local Services',
#  'Pets;Pet Services;Pet Groomers',
#  'Coffee & Tea;Food;Event Planning & Services;Donuts;Caterers',
#  'Barbers;Beauty & Spas',
#  'Yoga;Active Life;Trainers;Fitness & Instruction;Boot Camps',
#  'Grocery;International Grocery;Food;Korean;Ethical Grocery;Restaurants',
#  'Restaurants;Pizza',
#  'Motorcycle Repair;Motorcycle Dealers;Automotive',
#  'Noodles;Japanese;Barbeque;Diners;Restaurants',
#  'Car Dealers;Automotive',
#  'Hair Salons;Massage;Nail Salons;Beauty & Spas',
#  'Mexican;Restaurants',
#  'Pets;Veterinarians',
#  'Shopping;Bikes;Sporting Goods',
#  'Beauty & Spas;Skin Care;Hair Removal',
#  'Hair Stylists;Hair Extensions;Event Planning & Services;Blow Dry/Out Services;Beauty & Spas;Hair Salons;Wedding Planning',
#  'Pest Control;Local Services',
#  'Drywall Installation & Repair;Handyman;Home Services;Contractors;Damage Restoration',
#  'Pest Control;Local Services',
#  'Home Services;Real Estate;Apartments',
#  'Food;Coffee & Tea;Desserts',
#  'Food;Nightlife;Bars;Beer;Wine & Spirits;Wine Bars',
#  'Computers;Local Services;IT Services & Computer Repair;Shopping',
#  'Shopping;Flowers & Gifts;Arts & Entertainment;Cafes;Coffee & Tea;Restaurants;Local Flavor;Museums;Shopping Centers;Art Galleries;Florists;Food',
#  'Hospitals;Health & Medical;Professional Services;Hotels & Travel;Medical Centers;Walk-in Clinics;Travel Services',
#  'Hobby Shops;Shopping;Mobile Phones;Electronics',
#  'Home Services;Real Estate;Real Estate Agents;Real Estate Services',
#  'Community Service/Non-Profit;Arts & Entertainment;Local Services;Arcades;Social Clubs',
#  'Movers;Home Services',
#  'Discount Store;Food;Shopping;Electronics;Drugstores;Fashion;Department Stores;Mobile Phones;Grocery',
#  'Italian;Restaurants',
#  'Greek;Restaurants;Mediterranean',
#  'Contractors;Home Services;Heating & Air Conditioning/HVAC',
#  'Restaurants;Pizza',
#  'Adult Entertainment;Active Life;Gun/Rifle Ranges;Guns & Ammo;Nightlife;Shopping',
#  'Masonry/Concrete;Home Services;Landscaping',
#  'Office Cleaning;Home Cleaning;Home Organization;Professional Services;Home Services',
#  'Lighting Fixtures & Equipment;Shopping;Electricians;Home Services;Electronics',
#  'Laundromat;Local Services;Laundry Services;Dry Cleaning & Laundry',
#  'Public Services & Government;Local Services;Post Offices;Shipping Centers',
#  'Specialty Food;Seafood Markets;Sushi Bars;Food;Restaurants;Seafood;Japanese',
#  'Food;Coffee & Tea;Bakeries;Desserts',
#  'Beauty & Spas;Makeup Artists;Hair Removal;Day Spas;Hair Salons',
#  'Local Services;Shoe Repair',
#  'Indian;Restaurants;Pakistani',
#  'Food;Bakeries',
#  'Home Services;Real Estate;Real Estate Agents',
#  'Restaurants;Mexican',
#  'Breakfast & Brunch;Coffee & Tea;Restaurants;Food',
#  'Pet Groomers;Pets;Pet Services;Pet Sitting',
#  'Desserts;Food;Restaurants;Specialty Food;Chinese',
#  'Bridal;Fashion;Shopping;Flowers & Gifts',
#  'Hair Extensions;Beauty & Spas;Waxing;Skin Care;Hair Salons;Hair Removal;Permanent Makeup;Nail Salons;Eyelash Service',
#  'Health & Medical;Diagnostic Imaging;Medical Centers;Diagnostic Services',
#  'Beauty & Spas',
#  'Beauty & Spas;Day Spas',
#  'Hair Removal;Waxing;Beauty & Spas;Eyelash Service',
#  'General Dentistry;Dentists;Endodontists;Health & Medical;Cosmetic Dentists',
#  'Restaurants;Food;Coffee & Tea;Soup',
#  'Climbing;Local Services;Gyms;Fitness & Instruction;Active Life',
#  'Nail Salons;Beauty & Spas',
#  'Health & Medical;Cardiologists;Doctors',
#  'Automotive;Towing;Roadside Assistance',
#  'Pizza;Restaurants',
#  'Convenience Stores;Food;Automotive;Gas Stations',
#  'Event Planning & Services;Party Supplies',
#  'Local Services;IT Services & Computer Repair',
#  'Coffee & Tea;Food',
#  'Property Management;Home Services;Real Estate;Real Estate Agents;Real Estate Services',
#  'Home Services;Internet Service Providers;Professional Services',
#  'Appraisal Services;Real Estate Services;Local Services;Commercial Real Estate;Home Services;Real Estate',
#  'Shopping;Electronics',
#  'Pets;Pet Services;Pet Groomers;Pet Stores',
#  'Shipping Centers;Local Services',
#  'Sandwiches;Fast Food;Restaurants',
#  'Health & Medical;Chiropractors;Beauty & Spas;Massage;Acupuncture',
#  'Doctors;Health & Medical;Orthopedists',
#  'Transportation;Train Stations;Public Transportation;Hotels & Travel',
#  'Pet Sitting;Life Coach;Pet Services;Pets;Professional Services;Pet Training;Dog Walkers',
#  'Heating & Air Conditioning/HVAC;Home Services',
#  'Event Planning & Services;Sandwiches;Restaurants;Nightlife;American (Traditional);Salad;Cocktail Bars;Venues & Event Spaces;Bars',
#  'French;Restaurants',
#  'Chicken Wings;Restaurants;Pizza;Italian',
#  'Bars;Sports Bars;Arts & Entertainment;Casinos;Karaoke;Nightlife',
#  'Cinema;Arts & Entertainment',
#  'Beauty & Spas;Hair Salons',
#  'Screen Printing/T-Shirt Printing;Professional Services;Signmaking;Printing Services;Customized Merchandise;Screen Printing;Local Services;Engraving;Shopping',
#  'Wine Tours;Walking Tours;Hotels & Travel;Food Tours;Tours',
#  'Home & Garden;Shopping;Mattresses',
#  'Commercial Real Estate;Real Estate;Real Estate Services;Home Services;Property Management',
#  'Hotels & Travel;Car Rental',
#  'Italian;Restaurants;Pizza',
#  'Cupcakes;Custom Cakes;Desserts;Food',
#  'Lounges;Restaurants;Nightlife;Bars;Italian',
#  'Beauty & Spas;Blow Dry/Out Services;Hair Salons;Hair Stylists;Hair Extensions',
#  'Shopping;Books;Mags;Music & Video;Bookstores',
#  'Beauty & Spas;Massage;Cosmetics & Beauty Supply;Skin Care;Shopping',
#  'Burgers;Fast Food;American (New);American (Traditional);Breakfast & Brunch;Restaurants;Diners',
#  'Transportation;Hotels & Travel',
#  'Food;Specialty Food;Coffee & Tea',
#  'Dentists;Health & Medical;Endodontists',
#  'Drugstores;Discount Store;Fashion;Electronics;Grocery;Food;Mobile Phones;Shopping;Department Stores',
#  'Automotive;Auto Repair',
#  'Towing;Automotive',
#  'Education;Elementary Schools',
#  'Fashion;Department Stores;Shopping',
#  'American (New);Restaurants;Breakfast & Brunch;American (Traditional)',
#  'Home Services;Active Life;Swimming Pools;Pool Cleaners;Pool & Hot Tub Service',
#  'Local Services;Pest Control',
#  'Self Storage;Home Services;Local Services;Movers',
#  'Home Services;Contractors',
#  'Dog Walkers;Pet Services;Pets;Pet Sitting;Pet Transportation',
#  'Home Automation;Security Systems;Fire Protection Services;Home Services',
#  'Amateur Sports Teams;Professional Sports Teams;Arts & Entertainment;Active Life',
#  'Real Estate Services;Real Estate;Real Estate Agents;Home Services',
#  'Fish & Chips;Restaurants;Poutineries;Burgers',
#  'Mexican;Restaurants',
#  'Restaurants;Buffets',
#  'Makeup Artists;Beauty & Spas',
#  'Nail Salons;Beauty & Spas',
#  'Hobby Shops;Tabletop Games;Toy Stores;Comic Books;Shopping;Music & DVDs;Books;Mags;Music & Video',
#  'Furniture Reupholstery;Contractors;Local Services;Home Services;Furniture Repair;Refinishing Services;Cabinetry',
#  'Pilates;Yoga;Barre Classes;Active Life;Fitness & Instruction',
#  'Hair Removal;Beauty & Spas;Threading Services',
#  'Arts & Entertainment;Shopping;Art Galleries',
#  'Greek;Restaurants',
#  'Delis;Restaurants',
#  'Horseback Riding;Active Life;Tours;Hotels & Travel',
#  'Restaurants;Indian',
#  'Beauty & Spas;Nail Salons;Massage;Day Spas',
#  'Restaurants;Fast Food;Chinese',
#  'Ice Cream & Frozen Yogurt;Food;Desserts;Juice Bars & Smoothies',
#  'Auto Repair;Body Shops;Automotive',
#  'Food;Bakeries',
#  'Appliances & Repair;Local Services',
#  'Home Services;Local Services;Fences & Gates;Metal Fabricators;Windows Installation',
#  'Bars;American (Traditional);Restaurants;Sports Bars;Nightlife',
#  'Home Services;Home Cleaning',
#  'Food;Restaurants;Specialty Food;Mexican;Candy Stores;Ice Cream & Frozen Yogurt',
#  'Desserts;Food',
#  'Restaurants;Ethnic Food;Food;Chinese;Specialty Food',
#  'Nightlife;Pubs;Restaurants;Irish;Bars',
#  'Shutters;Damage Restoration;Contractors;Gutter Services;Home Services',
#  'Dance Studios;Fitness & Instruction;Active Life',
#  'Beauty & Spas;Eyelash Service;Waxing;Hair Removal;Nail Salons',
#  'Chinese;Restaurants',
#  'Waterproofing;Home Services;Water Purification Services',
#  'Restaurants;Chinese',
#  'Venues & Event Spaces;Dance Clubs;Event Planning & Services;Nightlife',
#  'Coffee & Tea;Bubble Tea;Tea Rooms;Food',
#  'American (New);Breakfast & Brunch;Restaurants',
#  'Restaurants;Japanese',
#  'Transportation;Hotels & Travel;Airlines;Travel Services',
#  'Restaurants;Bars;Nightlife;Pizza',
#  'Active Life;Amusement Parks;Kids Activities;Party & Event Planning;Event Planning & Services',
#  'Pet Groomers;Pet Services;Pets',
#  'Real Estate;Apartments;Home Services',
#  'Massage Therapy;Day Spas;Massage;Beauty & Spas;Reflexology;Health & Medical',
#  'Smog Check Stations;Automotive;Auto Parts & Supplies;Auto Electric Services;Oil Change Stations;Auto Repair;Body Shops',
#  'Active Life;Recreation Centers;Fitness & Instruction;Boot Camps;Gyms;Trainers',
#  'Restaurants;Italian;Pizza;Chicken Wings',
#  'Home Services;Mortgage Brokers;Real Estate',
#  'Na',
#  'Hair Removal;Waxing;Nail Salons;Beauty & Spas',
#  'Fashion;Shopping;Department Stores',
#  'Beauty & Spas;Nail Salons;Day Spas',
#  'Antiques;Shopping',
#  'Coffee & Tea;Restaurants;Bagels;Sandwiches;Food;Donuts',
#  'Event Planning & Services;Venues & Event Spaces;Golf;Active Life',
#  'Bakeries;Food',
#  'Pizza;Restaurants',
#  'Hotels;Hotels & Travel;Event Planning & Services',
#  'Oil Change Stations;Automotive;Car Dealers;Auto Repair;Auto Parts & Supplies',
#  'Middle Eastern;Restaurants',
#  'Nightlife;Restaurants;Bars;Italian',
#  'Thai;Restaurants',
#  'Food;Restaurants;Korean;Grocery',
#  'Restaurants;Fast Food',
#  'Restaurants;Seafood;Sandwiches',
#  'Fitness & Instruction;Gyms;Active Life',
#  'Pets;Pet Stores',
#  'Chinese;Thai;Food;Restaurants;Vietnamese',
#  'Active Life;Golf',
#  'Family Practice;Health & Medical;Doctors;Pediatricians',
#  'Delis;Sandwiches;Restaurants;Breakfast & Brunch',
#  'Hotels & Travel;Resorts',
#  'Used Car Dealers;Auto Repair;Car Dealers;Automotive',
#  'Beauty & Spas;Massage Therapy;Massage;Physical Therapy;Health & Medical',
#  'Property Management;Home Services;Real Estate',
#  'Bed & Breakfast;Event Planning & Services;Hotels & Travel;Hotels',
#  'Hotels & Travel;Tours',
#  'Hobby Shops;Shopping',
#  'Local Services;Bike Repair/Maintenance;Shopping;Food;Sporting Goods;Coffee & Tea;Bikes',
#  'Active Life;Parks;Dog Parks',
#  'Massage Therapy;Beauty & Spas;Health & Medical;Massage',
#  'Tattoo;Beauty & Spas',
#  'Food;Bakeries;Restaurants;Cafes',
#  'Active Life;Fitness & Instruction;Trainers;Gyms',
#  'Cosmetic Dentists;Orthodontists;Health & Medical;Dentists;General Dentistry',
#  'Active Life;Fitness & Instruction;Gyms;Sports Clubs;Trainers',
#  'Restaurants;Ice Cream & Frozen Yogurt;Shaved Ice;Hot Dogs;Food',
#  'Florists;Shopping;Flowers & Gifts',
#  'Health & Medical;Fitness & Instruction;Gyms;Active Life;Trainers;Nutritionists',
#  'Sushi Bars;Japanese;Restaurants',
#  'Burgers;Fast Food;Restaurants',
#  'Event Planning & Services;Session Photography;Event Photography;Photographers',
#  'Restaurants;Chicken Wings;Chicken Shop',
#  'Shopping;Jewelry',
#  'Barbers;Beauty & Spas;Hair Salons',
#  'Korean;Canadian (New);Restaurants;Tapas Bars',
#  'Active Life;Yoga;Pilates;Trainers;Fitness & Instruction',
#  'Hotels;Event Planning & Services;Hotels & Travel',
#  'American (Traditional);Burgers;Restaurants;Fast Food',
#  'Nail Salons;Waxing;Hair Removal;Beauty & Spas;Day Spas',
#  'Transmission Repair;Automotive;Oil Change Stations',
#  'Fitness & Instruction;Gyms;Active Life',
#  'Coffee & Tea;Food',
#  'Restaurants;Indian;Buffets',
#  'Fitness & Instruction;Trainers;Active Life;Gyms',
#  'Specialty Schools;First Aid Classes;CPR Classes;Education',
#  'Golf;Fitness & Instruction;Golf Lessons;Active Life',
#  'Doctors;Family Practice;Health & Medical',
#  'Himalayan/Nepalese;Restaurants',
#  'Health & Medical;Chiropractors',
#  'Sushi Bars;Restaurants;Nightlife;Lounges;American (New);Bars',
#  'Fitness & Instruction;Active Life;Martial Arts',
#  'Home Services;Windows Installation;Contractors',
#  'Financial Services;Banks & Credit Unions',
#  'Street Vendors;Festivals;Arts & Entertainment;Food',
#  'Guest Houses;Hotels & Travel;Venues & Event Spaces;Wedding Planning;Event Planning & Services;Nightlife;Arts & Entertainment;Music Venues',
#  'Sandwiches;Bakeries;Food;Chicken Wings;Cafes;Restaurants;Cajun/Creole',
#  'Desserts;Custom Cakes;Cupcakes;Food',
#  'Restaurants;Mexican;Fast Food',
#  'Health & Medical;Doctors',
#  'Pizza;Restaurants',
#  'Gas Stations;Automotive;Auto Repair',
#  'Day Spas;Beauty & Spas',
#  'Nail Salons;Beauty & Spas;Waxing;Hair Removal',
#  'Hot Dogs;Restaurants;Pizza;Burgers',
#  'Party & Event Planning;Hotels & Travel;Wedding Planning;Venues & Event Spaces;Hotels;Event Planning & Services',
#  'Barbers;Hair Salons;Beauty & Spas',
#  'Skin Care;Beauty & Spas;Nail Salons;Eyelash Service;Hair Removal;Waxing',
#  'Imported Food;Food;Grocery;Ethnic Food;Specialty Food',
#  'Convenience Stores;Food',
#  'Restaurants;Vegetarian;Live/Raw Food',
#  'Event Planning & Services;Wedding Planning;Floral Designers;Flowers & Gifts;Shopping;Florists',
#  'Restaurants;Fast Food;Creperies',
#  'Active Life;Fitness & Instruction;Martial Arts;Education',
#  'Local Services;Laundry Services;Dry Cleaning & Laundry',
#  'Fast Food;Restaurants;Burgers',
#  'Health & Medical;Doctors;Surgeons',
#  'Hotels;Event Planning & Services;Hotels & Travel',
#  'Event Planning & Services;Fitness & Instruction;Performing Arts;Local Services;Arts & Entertainment;Community Service/Non-Profit;Active Life;Venues & Event Spaces',
#  'Home Services;Garage Door Services',
#  'Active Life;Fitness & Instruction;Gyms',
#  'Auto Repair;Automotive',
#  'Auto Repair;Automotive;Tires',
#  'Burgers;Restaurants',
#  'Nail Salons;Beauty & Spas;Hair Salons',
#  'Active Life;Parks',
#  'Home Services;Water Purification Services;Plumbing',
#  'Shopping;Fashion',
#  'Home Services;Shades & Blinds',
#  'Health & Medical;Eyewear & Opticians;Optometrists;Shopping',
#  'Shopping;Baby Gear & Furniture',
#  'Farmers Market;Food',
#  'Food;Grocery;Convenience Stores',
#  'Hair Extensions;Hair Salons;Beauty & Spas;Makeup Artists',
#  'Food;Grocery',
#  'Food;Donuts;Desserts;Breakfast & Brunch;Restaurants;Coffee & Tea;Sandwiches;Bakeries',
#  'Beauty & Spas;Hair Removal;Hair Salons;Hair Extensions',
#  'Shopping;Hardware Stores;Hot Tub & Pool;Home & Garden',
#  'Public Services & Government;Local Services;Specialty Schools;Laboratory Testing;Diagnostic Services;CPR Classes;Walk-in Clinics;Medical Centers;Education;Fingerprinting;Health & Medical',
#  'Indian;Restaurants',
#  'Preschools;Child Care & Day Care;Education;Local Services',
#  'Automotive;Oil Change Stations;Auto Repair',
#  'Chocolatiers & Shops;Desserts;Flowers & Gifts;Shopping;Gift Shops;Candy Stores;Specialty Food;Food',
#  'Active Life;Skydiving;Hotels & Travel;Tours',
#  'Damage Restoration;Plumbing;Water Heater Installation/Repair;Home Services',
#  'Shopping;Home & Garden;Nurseries & Gardening',
#  'Steakhouses;Salad;Italian;Restaurants;Breakfast & Brunch;Seafood;American (New)',
#  'Buffets;Seafood;Restaurants',
#  'Sandwiches;Fast Food;Restaurants;Delis',
#  'Japanese;Korean;Restaurants',
#  'Grocery;Food',
#  'Food;Restaurants;Caribbean;Bakeries',
#  'Pizza;Restaurants;Cheesesteaks',
#  'Event Planning & Services;Caterers;Burgers;Greek;Restaurants;Middle Eastern;Mediterranean',
#  'Gas Stations;Automotive;Auto Repair;Auto Detailing',
#  'IT Services & Computer Repair;Internet Service Providers;Professional Services;Home Services;Local Services;Telecommunications;Television Service Providers',
#  'Shopping;Beauty & Spas;Cosmetics & Beauty Supply',
#  'British;Cafes;Restaurants',
#  'Bail Bondsmen;Local Services;Financial Services',
#  'Home Services;Home Cleaning',
#  'Restaurants;Caribbean',
#  'Antiques;Shopping;Home & Garden;Home Decor',
#  'Nail Salons;Beauty & Spas',
#  'Tires;Windshield Installation & Repair;Oil Change Stations;Auto Repair;Automotive',
#  'American (New);Restaurants;Pubs;Nightlife;Sports Bars;Bars;Food;Pizza;Breweries',
#  'Food;Specialty Food;Candy Stores',
#  'Auto Upholstery;Furniture Reupholstery;Local Services;Automotive',
#  'Fast Food;Delis;Restaurants;Sandwiches',
#  'Gas Stations;Food;Convenience Stores;Automotive',
#  'Food;Grocery',
#  'Door Sales/Installation;Windows Installation;Garage Door Services;Fences & Gates;Home Services',
#  'Restaurants;Chinese',
#  'Restaurants;Tacos;Mexican',
#  'Hawaiian;Asian Fusion;Restaurants;Korean',
#  'Tanning;Beauty & Spas',
#  'Hotels;Event Planning & Services;Casinos;Resorts;Arts & Entertainment;Hotels & Travel',
#  'Arts & Entertainment;Restaurants;Buffets;American (Traditional);Casinos',
#  'Tai Chi;Active Life;Yoga;Fitness & Instruction',
#  'Ice Cream & Frozen Yogurt;Food',
#  'Refinishing Services;Local Services;Flooring;Home Services;Carpet Cleaning;Painters;Pressure Washers;Masonry/Concrete',
#  'Pizza;Restaurants',
#  'Local Services;Appliances & Repair',
#  'Beauty & Spas;Hair Salons',
#  'Beauty & Spas;Barbers',
#  'Apartments;Real Estate;Home Services',
#  'Food;Coffee & Tea',
#  'Eyebrow Services;Beauty & Spas;Hair Salons',
#  'Salad;Sandwiches;Restaurants;American (New);Pizza',
#  'Auto Repair;Automotive;Body Shops',
#  'Bars;Music Venues;Nightlife;Arts & Entertainment',
#  'Vape Shops;Local Services;Tobacco Shops;Shopping',
#  'Restaurants;Fast Food;Burgers',
#  'Arts & Entertainment;Virtual Reality Centers;Bars;Restaurants;Arcades;American (New);Food;Nightlife',
#  'Restaurants;Mexican',
#  'Musical Instruments & Teachers;Shopping',
#  'Food;Salad;Sandwiches;Restaurants;Breakfast & Brunch;Bagels;Soup',
#  'Shopping;Specialty Food;Vitamins & Supplements;Health Markets;Food',
#  'Automotive;Auto Repair',
#  'Health & Medical;Dentists;General Dentistry;Doctors',
#  'Restaurants;Vegetarian;Soup',
#  'Seafood;Restaurants',
#  'Restaurants;Whiskey Bars;Nightlife;Bars;American (Traditional);Cocktail Bars;Dance Clubs;Lounges',
#  'Restaurants;Pizza',
#  'Pets;Veterinarians',
#  'Hair Salons;Beauty & Spas;Barbers',
#  'Italian;Chicken Wings;Pizza;Restaurants',
#  'Vegetarian;Nightlife;Mexican;Bars;Vegan;Restaurants;Breakfast & Brunch;Cafes',
#  'Restaurants;Mexican',
#  'Mobile Phones;Professional Services;Internet Service Providers;Home Services;Mobile Phone Accessories;Shopping',
#  'Restaurants;Sandwiches',
#  'Restaurants;American (Traditional)',
#  'Restaurants;Chinese',
#  'Beauty & Spas;Day Spas;Skin Care',
#  'Acupuncture;Reflexology;Massage;Physical Therapy;Health & Medical;Beauty & Spas',
#  'Health & Medical;Skin Care;Plastic Surgeons;Cosmetic Surgeons;Beauty & Spas;Doctors;Medical Spas;Medical Centers',
#  'Outdoor Gear;Sports Wear;Sporting Goods;Fashion;Shopping',
#  'Restaurants;Canadian (New);American (New);Cafes;French',
#  'Hair Removal;Doctors;Laser Hair Removal;Health & Medical;Dermatologists;Beauty & Spas;Medical Spas;Skin Care',
#  'Bars;Beer;Wine & Spirits;Canadian (New);Nightlife;Food;Restaurants',
#  'Local Services;Appliances & Repair',
#  'Gas Stations;Convenience Stores;Food;Automotive',
#  'Pet Services;Pets;Pet Groomers',
#  'Event Planning & Services;Photographers;Session Photography',
#  'Home Services;Real Estate;Apartments',
#  'Health & Medical;Chiropractors',
#  'Permanent Makeup;Beauty & Spas;Piercing;Arts & Entertainment;Tattoo',
#  'Videos & Video Game Rental;Books;Mags;Music & Video;Music & DVDs;Shopping',
#  'Antiques;Home & Garden;Shopping',
#  'Restaurants;Italian',
#  'Sporting Goods;Motorcycle Dealers;Automotive;Active Life;Shopping;Bike Rentals;Bikes',
#  'Bed & Breakfast;Breakfast & Brunch;Salad;American (Traditional);Hotels & Travel;Restaurants;Comfort Food',
#  'Real Estate;Home Services;Financial Services;Banks & Credit Unions;Mortgage Brokers',
#  'Sandwiches;Fast Food;Restaurants;Delis',
#  'Nightlife;Restaurants;Southern;Gastropubs;Bars;Pubs',
#  'Tattoo Removal;Doctors;Skin Care;Massage Therapy;Health & Medical;Laser Hair Removal;Cosmetic Surgeons;Hair Removal;Beauty & Spas;Medical Spas',
#  'Mexican;Restaurants',
#  'Home & Garden;Shopping;Home Decor',
#  'Fast Food;Chicken Shop;American (Traditional);Chicken Wings;Restaurants',
#  'Beauty & Spas;Massage Therapy;Occupational Therapy;Massage;Health & Medical;Physical Therapy',
#  'Restaurants;Fast Food;Mexican',
#  'Middle Eastern;Restaurants;Indian;Food;American (New);Afghan',
#  'Parks;Pets;Dog Parks;Active Life',
#  'Bagels;Food',
#  'Restaurants;Mexican',
#  'Cosmetics & Beauty Supply;Shopping;Barbers;Beauty & Spas',
#  'Lounges;Nightlife;Bars',
#  'Hair Salons;Barbers;Beauty & Spas',
#  'Restaurants;Food Stands;Street Vendors;Food;Mexican',
#  'Food;Gas Stations;Automotive;Convenience Stores',
#  'Automotive;Oil Change Stations;Auto Repair',
#  'Fashion;Accessories;Jewelry;Sewing & Alterations;Local Services;Bridal;Shopping',
#  'Cosmetic Dentists;Oral Surgeons;Dentists;Health & Medical;General Dentistry;Medical Centers',
#  'Restaurants;Ethiopian',
#  'Caribbean;Restaurants',
#  'Nail Salons;Beauty & Spas;Hair Salons',
#  'Water Heater Installation/Repair;Plumbing;Home Services',
#  'Food;Cafes;Coffee & Tea;Restaurants;Breakfast & Brunch',
#  'Creperies;Restaurants;Cafes',
#  'Hair Salons;Beauty & Spas',
#  'Hair Salons;Beauty & Spas;Hair Stylists;Barbers;Tanning',
#  'Beauty & Spas;Day Spas',
#  'Trainers;Fitness & Instruction;Health & Medical;Gyms;Active Life;Weight Loss Centers',
#  'Pizza;Fast Food;Restaurants',
#  'Restaurants;Italian',
#  'Day Spas;Beauty & Spas',
#  'Na',
#  'Restaurants;Pizza',
#  'Restaurants;Fast Food;Burgers',
#  'Active Life;Yoga;Fitness & Instruction',
#  'Day Spas;Restaurants;Beauty & Spas;Massage;Russian',
#  'Hair Salons;Beauty & Spas',
#  'Restaurants;Chicken Wings',
#  'Chinese;Restaurants',
#  'Irish;Bars;Nightlife;Restaurants',
#  'Heating & Air Conditioning/HVAC;Home Services',
#  'Event Planning & Services;Caterers',
#  'RV Repair;RV Dealers;Auto Repair;Automotive',
#  'Medical Centers;Health & Medical',
#  'Arts & Entertainment;Specialty Schools;Education;Art Schools',
#  'Restaurants;Burgers;Fast Food',
#  'Oil Change Stations;Auto Parts & Supplies;Tires;Automotive;Auto Repair',
#  'Wheel & Rim Repair;Auto Parts & Supplies;Tires;Automotive',
#  'Pizza;Restaurants',
#  'Flowers & Gifts;Jewelry;Accessories;Fashion;Shopping;Gift Shops',
#  'Pizza;Restaurants;Chicken Wings;Sandwiches',
#  'Home Services;Property Management;Real Estate',
#  'Home Services;Real Estate Agents;Real Estate;Real Estate Services',
#  'Sandwiches;Restaurants',
#  'Fast Food;Mexican;Restaurants',
#  'Japanese;Restaurants;Sandwiches;Burgers',
#  'Wholesale Stores;Shopping',
#  'Restaurants;Burgers;Breakfast & Brunch;Diners;Food;Desserts',
#  'Dentists;General Dentistry;Oral Surgeons;Health & Medical;Cosmetic Dentists',
#  'Restaurants;Mexican',
#  'Sleep Specialists;Health & Medical;Neurologist;Doctors',
#  'Health & Medical;Doctors',
#  'Bars;African;Cocktail Bars;Restaurants;Nightlife',
#  'Soccer;Fitness & Instruction;Active Life;Sports Clubs',
#  'Hair Salons;Beauty & Spas',
#  'Beauty & Spas;Nightlife;Bars;Barbers',
#  'Health & Medical;Spine Surgeons;Ear Nose & Throat;Doctors;Cosmetic Surgeons;Neurologist',
#  'Restaurants;Fast Food',
#  'Education;Specialty Schools;Talent Agencies;Professional Services;Performing Arts;Arts & Entertainment',
#  'Hospitals;Health & Medical',
#  'Beauty & Spas;Hair Salons',
#  'Beauty & Spas;Day Spas',
#  'Indian;Barbeque;Fast Food;Restaurants',
#  'Cinema;Arts & Entertainment',
#  'Casinos;Nightlife;Arts & Entertainment;Pool Halls',
#  'Pet Services;Pet Groomers;Pets;Pet Stores',
#  'Body Shops;Towing;Auto Repair;Automotive',
#  'Restaurants;Vietnamese',
#  'Food;Grocery',
#  'Bakeries;Food',
#  'Professional Services',
#  'Title Loans;Auto Loan Providers;Check Cashing/Pay-day Loans;Automotive;Financial Services',
#  'Pizza;Restaurants;Chicken Wings;Italian',
#  'Food Trucks;Shaved Ice;Ice Cream & Frozen Yogurt;Food',
#  'Bars;Lounges;Karaoke;Restaurants;Sandwiches;Seafood;Nightlife;American (Traditional)',
#  'Restaurants',
#  'Endodontists;General Dentistry;Cosmetic Dentists;Dentists;Orthodontists;Health & Medical',
#  'Doctors;Preventive Medicine;Health & Medical;Medical Spas;Medical Centers;Beauty & Spas',
#  'Local Flavor',
#  'Shopping;Drugstores',
#  'Home Services;Landscaping;Florists;Home & Garden;Nurseries & Gardening;Shopping;Flowers & Gifts',
#  'Financial Services;Banks & Credit Unions',
#  'Mexican;Food;Restaurants;Tex-Mex',
#  'Contractors;Landscape Architects;Home Services;Landscaping',
#  'Beauty & Spas;Hair Salons',
#  'Beauty & Spas;Health & Medical;Reflexology;Massage',
#  'Libraries;Public Services & Government',
#  'Session Photography;Painters;Videographers;Photographers;Real Estate Photography;Real Estate;Hotels & Travel;Event Photography;Home Services;Travel Services;Real Estate Services;Event Planning & Services;Wedding Chapels',
#  'Beauty & Spas;Hair Salons',
#  'Health & Medical;Dentists;General Dentistry',
#  'Property Management;Home Services;Real Estate',
#  'Public Services & Government;Post Offices',
#  'Shopping;Local Services;Thrift Stores;Community Service/Non-Profit',
#  'Mexican;Restaurants',
#  'Sandwiches;Restaurants;Fast Food',
#  'Coffee & Tea;Desserts;Juice Bars & Smoothies;Food;Ice Cream & Frozen Yogurt',
#  'Sporting Goods;Bikes;Bike Rentals;Shopping;Active Life',
#  'Shopping;Vape Shops;Tobacco Shops;Public Services & Government;Hobby Shops;Local Services',
#  'Local Services;Signmaking;Printing Services;Professional Services;Shipping Centers',
#  'Plumbing;Septic Services;Contractors;Home Services;Heating & Air Conditioning/HVAC;Local Services;Water Heater Installation/Repair',
#  'Beauty & Spas;Nail Salons',
#  'Auto Repair;Automotive',
#  'Bakeries;Soup;Sandwiches;Salad;Food;Restaurants',
#  'Shoe Stores;Fashion;Shopping',
#  'Burgers;Sports Bars;Bars;Restaurants;Nightlife',
#  'Hair Extensions;Hair Salons;Blow Dry/Out Services;Hair Stylists;Beauty & Spas',
#  'Local Services;Self Storage',
#  'Hotels & Travel;Event Planning & Services;Hotels',
#  'Restaurants;Thai',
#  'Bars;Lounges;Nightlife;Dance Clubs',
#  'Nightlife;Pubs;French;Bars;Japanese;Restaurants',
#  'Gymnastics;Active Life',
#  'Na',
#  'Food;Fast Food;American (Traditional);Restaurants;Cheesesteaks;Ice Cream & Frozen Yogurt;Burgers',
#  'Dentists;Medical Centers;General Dentistry;Oral Surgeons;Health & Medical',
#  'Bookstores;Shopping;Books;Mags;Music & Video',
#  'Barbers;Beauty & Spas',
#  'Asian Fusion;Restaurants;Nightlife;Lounges;Bars;Korean',
#  'Food;Bakeries',
#  'Nail Salons;Beauty & Spas',
#  'Beauty & Spas;Nail Salons',
#  'Food;Health & Medical;Wedding Planning;Juice Bars & Smoothies;Event Planning & Services;Nutritionists;Party & Event Planning;Food Delivery Services;Personal Chefs;Caterers',
#  'American (New);Restaurants',
#  'American (New);Nightlife;Restaurants;Bars',
#  'Pool Halls;Nightlife',
#  'Siding;Waterproofing;Roof Inspectors;Roofing;Home Services',
#  'Cannabis Dispensaries;Shopping',
#  'Breakfast & Brunch;Burgers;Restaurants;Salad;Sandwiches',
#  'Shopping;Jewelry',
#  'Restaurants;Mexican',
#  'Food;Coffee & Tea;Donuts',
#  ...]

# %%
new_list=[]
for item in categories_list2:
    split_item=item.split(';')
    new_list+=split_item
new_list
# Out:
# ['Dentists',
#  'General Dentistry',
#  'Health & Medical',
#  'Oral Surgeons',
#  'Cosmetic Dentists',
#  'Orthodontists',
#  'Hair Stylists',
#  'Hair Salons',
#  "Men's Hair Salons",
#  'Blow Dry/Out Services',
#  'Hair Extensions',
#  'Beauty & Spas',
#  'Departments of Motor Vehicles',
#  'Public Services & Government',
#  'Sporting Goods',
#  'Shopping',
#  'American (New)',
#  'Nightlife',
#  'Bars',
#  'Sandwiches',
#  'American (Traditional)',
#  'Burgers',
#  'Restaurants',
#  'Italian',
#  'Restaurants',
#  'Real Estate Services',
#  'Real Estate',
#  'Home Services',
#  'Property Management',
#  'Shopping',
#  'Sporting Goods',
#  'Coffee & Tea',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Automotive',
#  'Auto Detailing',
#  'Breakfast & Brunch',
#  'Gluten-Free',
#  'Coffee & Tea',
#  'Food',
#  'Restaurants',
#  'Sandwiches',
#  'Local Services',
#  'Self Storage',
#  'Bakeries',
#  'Bagels',
#  'Food',
#  'General Dentistry',
#  'Dentists',
#  'Endodontists',
#  'Cosmetic Dentists',
#  'Health & Medical',
#  'Orthodontists',
#  'Restaurants',
#  'American (Traditional)',
#  'Italian',
#  'French',
#  'Restaurants',
#  'Beauty & Spas',
#  'Nail Salons',
#  'Tires',
#  'Oil Change Stations',
#  'Auto Repair',
#  'Automotive',
#  'Barbers',
#  'Beauty & Spas',
#  'French',
#  'Food',
#  'Bakeries',
#  'Restaurants',
#  'Food',
#  'Coffee & Tea',
#  'Shopping',
#  'Books',
#  'Mags',
#  'Music & Video',
#  'Music & DVDs',
#  'Public Services & Government',
#  'Fitness & Instruction',
#  'Sports Clubs',
#  'Gyms',
#  'Trainers',
#  'Active Life',
#  'Bars',
#  'Sports Bars',
#  'Nightlife',
#  'Tiki Bars',
#  'Nightlife',
#  'Mexican',
#  'Restaurants',
#  'Bars',
#  'Shopping',
#  'Jewelry',
#  'Watch Repair',
#  'Local Services',
#  'Coffee & Tea',
#  'Food',
#  'Tea Rooms',
#  'Soup',
#  'Salad',
#  'Sandwiches',
#  'Restaurants',
#  'Food',
#  'American (Traditional)',
#  'Coffee & Tea',
#  'Restaurants',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Oil Change Stations',
#  'Smog Check Stations',
#  'Automotive',
#  'Auto Repair',
#  'Arts & Entertainment',
#  'Festivals',
#  'Restaurants',
#  'French',
#  'Gastropubs',
#  'Coffee & Tea',
#  'Restaurants',
#  'Food',
#  'Mediterranean',
#  'Tea Rooms',
#  'Nail Salons',
#  'Beauty & Spas',
#  'Nightlife',
#  'Pubs',
#  'Bars',
#  'Home Services',
#  'Contractors',
#  'Pool & Hot Tub Service',
#  'Pool Cleaners',
#  'Hair Salons',
#  'Blow Dry/Out Services',
#  'Hair Stylists',
#  'Beauty & Spas',
#  'Hair Extensions',
#  'Home & Garden',
#  'Furniture Stores',
#  'Shopping',
#  'Event Planning & Services',
#  'Caterers',
#  'Nightlife',
#  'Izakaya',
#  'Comfort Food',
#  'Cocktail Bars',
#  'Asian Fusion',
#  'Bars',
#  'Japanese',
#  'Restaurants',
#  'Gastropubs',
#  'Tapas/Small Plates',
#  'Home Services',
#  'Lighting Fixtures & Equipment',
#  'Local Services',
#  'Electricians',
#  'TV Mounting',
#  'Desserts',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Shopping',
#  'Guns & Ammo',
#  'Restaurants',
#  'Italian',
#  'Seafood',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'Burgers',
#  'Restaurants',
#  'Tanning',
#  'Day Spas',
#  'Spray Tanning',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Nurseries & Gardening',
#  'Home & Garden',
#  'Shopping',
#  'Arts & Entertainment',
#  'Performing Arts',
#  'Italian',
#  'Restaurants',
#  'Hotels & Travel',
#  'Car Rental',
#  'Nightlife',
#  'Bars',
#  'Barbeque',
#  'Sports Bars',
#  'American (New)',
#  'Restaurants',
#  'Fast Food',
#  'Restaurants',
#  'Sandwiches',
#  'Arcades',
#  'Arts & Entertainment',
#  'Gastropubs',
#  'Restaurants',
#  'American (New)',
#  'Restaurants',
#  'Mexican',
#  'Active Life',
#  'Fitness & Instruction',
#  'Gyms',
#  'Restaurants',
#  'Chinese',
#  'Eyelash Service',
#  'Beauty & Spas',
#  'Automotive',
#  'Auto Repair',
#  'Education',
#  'Performing Arts',
#  'Specialty Schools',
#  'Art Schools',
#  'Arts & Entertainment',
#  'Food',
#  'Coffee & Tea',
#  'Desserts',
#  'Automotive',
#  'Body Shops',
#  'Auto Glass Services',
#  'Home Cleaning',
#  'Home Services',
#  'Window Washing',
#  'Cafes',
#  'Restaurants',
#  'Health & Medical',
#  'General Dentistry',
#  'Dentists',
#  'Office Cleaning',
#  'Carpet Cleaning',
#  'Professional Services',
#  'Home Cleaning',
#  'Home Services',
#  'Local Services',
#  'Home Services',
#  'Television Service Providers',
#  'Home Automation',
#  'Home Theatre Installation',
#  'Professional Services',
#  'Breakfast & Brunch',
#  'Diners',
#  'Restaurants',
#  'Cafes',
#  'British',
#  'Bakeries',
#  'Food',
#  'Doctors',
#  'Health & Medical',
#  'Orthopedists',
#  'Health & Medical',
#  'Doctors',
#  'Restaurants',
#  'Burgers',
#  'Fast Food',
#  'Sporting Goods',
#  'Shopping',
#  "Men's Clothing",
#  "Women's Clothing",
#  'Fashion',
#  'Shopping',
#  'Restaurants',
#  'Sandwiches',
#  'Coffee & Tea',
#  'Food',
#  'Breakfast & Brunch',
#  'Bagels',
#  'Restaurants',
#  'Bakeries',
#  'Sandwiches',
#  'Food',
#  'Hotels',
#  'Event Planning & Services',
#  'Hotels & Travel',
#  'Shopping',
#  'Public Services & Government',
#  'Departments of Motor Vehicles',
#  'Health & Medical',
#  'Chiropractors',
#  'Restaurants',
#  'Pizza',
#  'American (Traditional)',
#  'Nightlife',
#  'Dive Bars',
#  'Restaurants',
#  'Bars',
#  'Performing Arts',
#  'Arts & Entertainment',
#  'Beauty & Spas',
#  'Piercing',
#  'Tattoo',
#  'Watch Repair',
#  'Jewelry Repair',
#  'Shopping',
#  'Local Services',
#  'Jewelry',
#  'Event Planning & Services',
#  'Nightlife',
#  'Lounges',
#  'Venues & Event Spaces',
#  'Bars',
#  'Imported Food',
#  'Specialty Food',
#  'Thai',
#  'Ethnic Food',
#  'Food',
#  'Restaurants',
#  'Florists',
#  'Wholesale Stores',
#  'Shopping',
#  'Flowers & Gifts',
#  'Marketing',
#  "Men's Clothing",
#  'Restaurants',
#  'Graphic Design',
#  "Women's Clothing",
#  'Screen Printing',
#  'Advertising',
#  'Pizza',
#  'Shopping',
#  'Web Design',
#  'Fashion',
#  'Local Services',
#  'Screen Printing/T-Shirt Printing',
#  'Professional Services',
#  'Venues & Event Spaces',
#  'Event Planning & Services',
#  'Restaurants',
#  'Italian',
#  'Italian',
#  'Restaurants',
#  'Real Estate Agents',
#  'Home Services',
#  'Real Estate',
#  'Optometrists',
#  'Doctors',
#  'Internal Medicine',
#  'Health & Medical',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Religious Organizations',
#  'Restaurants',
#  'Chinese',
#  'Food Court',
#  'Restaurants',
#  'Cuban',
#  'Nightlife',
#  'Adult Entertainment',
#  'Strip Clubs',
#  'Education',
#  'Dance Schools',
#  'Arts & Entertainment',
#  'Fitness & Instruction',
#  'Specialty Schools',
#  'Active Life',
#  'Dance Studios',
#  'Performing Arts',
#  'Pets',
#  'Veterinarians',
#  'Restaurants',
#  'Gluten-Free',
#  'Indian',
#  'Seafood',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'Tires',
#  'Automotive',
#  'Pizza',
#  'Food',
#  'Internet Cafes',
#  'Restaurants',
#  'Caribbean',
#  'Breakfast & Brunch',
#  'Food',
#  'Coffee & Tea',
#  'Canadian (New)',
#  'Restaurants',
#  'Weight Loss Centers',
#  'Physical Therapy',
#  'Health & Medical',
#  'Pet Groomers',
#  'Pet Sitting',
#  'Pets',
#  'Pet Services',
#  'Pet Training',
#  'American (Traditional)',
#  'Restaurants',
#  'Seafood',
#  'Food',
#  'Donuts',
#  'Kitchen & Bath',
#  'Countertop Installation',
#  'Home Services',
#  'Tiling',
#  'Contractors',
#  'Shopping',
#  'Home & Garden',
#  'Local Services',
#  'Appliances & Repair',
#  'Veterinarians',
#  'Pets',
#  'Contractors',
#  'Arts & Crafts',
#  'Shopping',
#  'Flooring',
#  'Home Services',
#  'Indian',
#  'Restaurants',
#  'Fast Food',
#  'Smog Check Stations',
#  'Automotive',
#  'Auto Repair',
#  'Body Shops',
#  'Art Galleries',
#  'Arts & Entertainment',
#  'Head Shops',
#  'Tobacco Shops',
#  'Shopping',
#  'Italian',
#  'Chicken Wings',
#  'Fast Food',
#  'Restaurants',
#  'Pizza',
#  'Food',
#  'Restaurants',
#  'Tacos',
#  'Food Trucks',
#  'Mexican',
#  'Pizza',
#  'Restaurants',
#  'Massage',
#  'Massage Therapy',
#  'Health & Medical',
#  'Skin Care',
#  'Day Spas',
#  'Beauty & Spas',
#  'Vegan',
#  'American (New)',
#  'Restaurants',
#  'Sandwiches',
#  'Salad',
#  'Wraps',
#  'Food',
#  'Automotive',
#  'Motorcycle Repair',
#  'Restaurants',
#  'Fast Food',
#  'Burgers',
#  'Health & Medical',
#  'Counseling & Mental Health',
#  'Department Stores',
#  'Home Decor',
#  'Shopping',
#  'Fashion',
#  "Women's Clothing",
#  'Discount Store',
#  'Home & Garden',
#  "Men's Clothing",
#  'Wedding Planning',
#  'Venues & Event Spaces',
#  'Shopping',
#  'Bridal',
#  'Event Planning & Services',
#  'Buffets',
#  'Restaurants',
#  'Sushi Bars',
#  'Chinese',
#  'Cafes',
#  'Nightlife',
#  'Wine Bars',
#  'Bars',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Food',
#  'Coffee & Tea',
#  'Donuts',
#  'Restaurants',
#  'Home Services',
#  'Air Duct Cleaning',
#  'Local Services',
#  'Heating & Air Conditioning/HVAC',
#  'Food',
#  'Delis',
#  'Fast Food',
#  'Sandwiches',
#  'Restaurants',
#  'Automotive',
#  'Tires',
#  'Auto Repair',
#  'Auto Parts & Supplies',
#  'Oil Change Stations',
#  'Burgers',
#  'Restaurants',
#  'Restaurants',
#  'Cafes',
#  'American (New)',
#  'Bars',
#  'Nightlife',
#  'Wine Bars',
#  'Shopping',
#  'Drugstores',
#  'Burgers',
#  'Fast Food',
#  'Restaurants',
#  'Optometrists',
#  'Health & Medical',
#  'Eyewear & Opticians',
#  'Shopping',
#  'Tobacco Shops',
#  'Hobby Shops',
#  'Shopping',
#  'Home Services',
#  'Grout Services',
#  'Carpet Cleaning',
#  'Damage Restoration',
#  'Home Cleaning',
#  'Local Services',
#  'Party & Event Planning',
#  'Wedding Planning',
#  'Event Planning & Services',
#  'Office Equipment',
#  'Shopping',
#  'Convenience Stores',
#  'Desserts',
#  'Food Delivery Services',
#  'Food',
#  'Grocery',
#  'Restaurants',
#  'Food',
#  'Vietnamese',
#  'Arcades',
#  'Arts & Entertainment',
#  'Party & Event Planning',
#  'Escape Games',
#  'Event Planning & Services',
#  'Active Life',
#  'Beauty & Spas',
#  'Nail Salons',
#  'Sandwiches',
#  'Restaurants',
#  'Fast Food',
#  'Restaurants',
#  'Coffee & Tea',
#  'Cafes',
#  'German',
#  'Food',
#  'Comedy Clubs',
#  'Nightlife',
#  'Shopping',
#  'Food',
#  'Bakeries',
#  'Donuts',
#  'Hotels & Travel',
#  'Event Planning & Services',
#  'Hotels',
#  'Chocolatiers & Shops',
#  'Desserts',
#  'Specialty Food',
#  'Food',
#  'Health & Medical',
#  'Active Life',
#  'Weight Loss Centers',
#  'Fitness & Instruction',
#  'Trainers',
#  'Nutritionists',
#  'Gyms',
#  'Pest Control',
#  'Local Services',
#  'Donuts',
#  'Food',
#  'Restaurants',
#  'Sushi Bars',
#  'Japanese',
#  'Asian Fusion',
#  'Food',
#  'Coffee & Tea',
#  'Massage',
#  'Beauty & Spas',
#  'Restaurants',
#  'Creperies',
#  'Mobile Phones',
#  'IT Services & Computer Repair',
#  'Shopping',
#  'Electronics Repair',
#  'Mobile Phone Repair',
#  'Local Services',
#  'Pizza',
#  'Restaurants',
#  'Arts & Entertainment',
#  'Performing Arts',
#  'Plumbing',
#  'Home Services',
#  'Restaurants',
#  'Chinese',
#  'Hair Salons',
#  'Beauty & Spas',
#  'Nail Salons',
#  'Seafood Markets',
#  'Food',
#  'Specialty Food',
#  'Health Markets',
#  'Food',
#  'Beauty & Spas',
#  'Specialty Food',
#  'Shopping',
#  'Cosmetics & Beauty Supply',
#  'Tobacco Shops',
#  'Shopping',
#  'Vape Shops',
#  'Musical Instruments & Teachers',
#  'Shopping',
#  'Restaurants',
#  'Sandwiches',
#  'Delicatessen',
#  'Asian Fusion',
#  'Food',
#  'Cafes',
#  'Septic Services',
#  'Home Services',
#  'Plumbing',
#  'Local Services',
#  'Blow Dry/Out Services',
#  'Hair Salons',
#  'Barbers',
#  'Hair Stylists',
#  'Beauty & Spas',
#  'Food',
#  'Local Flavor',
#  'Canadian (New)',
#  'Sugar Shacks',
#  'Restaurants',
#  'American (Traditional)',
#  'Eyewear & Opticians',
#  'Health & Medical',
#  'Shopping',
#  'Optometrists',
#  'Restaurants',
#  'Thai',
#  'Vietnamese',
#  'Chinese',
#  'Hotels & Travel',
#  'Transportation',
#  'Public Transportation',
#  'Electricians',
#  'Home Services',
#  'Heating & Air Conditioning/HVAC',
#  'Plumbing',
#  'Hiking',
#  'Active Life',
#  'Shopping',
#  'Fashion',
#  'Shoe Stores',
#  'Restaurants',
#  'American (Traditional)',
#  'Italian',
#  'Pizza',
#  'Restaurants',
#  'Salad',
#  'Mexican',
#  'Tex-Mex',
#  'Restaurants',
#  'Fast Food',
#  'Pizza',
#  'Restaurants',
#  'Fast Food',
#  'Burgers',
#  'Restaurants',
#  'Hotels',
#  'Restaurants',
#  'Event Planning & Services',
#  'American (New)',
#  'Hotels & Travel',
#  'Shopping',
#  'Adult',
#  'Italian',
#  'Restaurants',
#  'Auto Parts & Supplies',
#  'Automotive',
#  'Auto Repair',
#  'Tiling',
#  'Carpet Cleaning',
#  'Home Services',
#  'Refinishing Services',
#  'Local Services',
#  'Fashion',
#  "Women's Clothing",
#  'Accessories',
#  'Shopping',
#  'Accessories',
#  "Women's Clothing",
#  'Fashion',
#  'Shopping',
#  'Wedding Planning',
#  'Fashion',
#  'Formal Wear',
#  'Event Planning & Services',
#  'Bridal',
#  'Party & Event Planning',
#  'Shopping',
#  'Restaurants',
#  'Greek',
#  'Salad',
#  'Mediterranean',
#  'Nightlife',
#  'Japanese',
#  'Music Venues',
#  'Ramen',
#  'Arts & Entertainment',
#  'Restaurants',
#  'Bars',
#  'Real Estate Services',
#  'Real Estate',
#  'Home Services',
#  'Automotive',
#  'Gas Stations',
#  'Bakeries',
#  'Coffee & Tea',
#  'Bubble Tea',
#  'Food',
#  'Active Life',
#  'Parks',
#  'Playgrounds',
#  'Sewing & Alterations',
#  'Local Services',
#  'Shoe Repair',
#  'Automotive',
#  'Auto Detailing',
#  'Mobile Dent Repair',
#  'Auto Upholstery',
#  'Auto Glass Services',
#  'Day Spas',
#  'Hair Salons',
#  'Beauty & Spas',
#  'Sewing & Alterations',
#  'Local Services',
#  'Massage',
#  'Nail Salons',
#  'Skin Care',
#  'Day Spas',
#  'Beauty & Spas',
#  'Active Life',
#  'Sports Clubs',
#  'Gyms',
#  'Fitness & Instruction',
#  'Trainers',
#  'Motorcycle Repair',
#  'Automotive',
#  'Motorcycle Dealers',
#  'Photography Stores & Services',
#  'Shopping',
#  'Beauty & Spas',
#  'Cosmetics & Beauty Supply',
#  'Drugstores',
#  'Automotive',
#  'Auto Repair',
#  'Body Shops',
#  'Yoga',
#  'Active Life',
#  'Fitness & Instruction',
#  'Tex-Mex',
#  'Mexican',
#  'Restaurants',
#  'Fast Food',
#  'Shopping',
#  'Health & Medical',
#  'Eyewear & Opticians',
#  'Optometrists',
#  'Local Services',
#  'Home Services',
#  'Plumbing',
#  'Septic Services',
#  'Water Heater Installation/Repair',
#  'Pets',
#  'Veterinarians',
#  'Pet Services',
#  'Pet Groomers',
#  'Pet Sitting',
#  'Juice Bars & Smoothies',
#  'Food',
#  'Churches',
#  'Religious Organizations',
#  'Home & Garden',
#  'Active Life',
#  'Home Decor',
#  'Shopping',
#  'Discount Store',
#  'Furniture Stores',
#  'Swimming Pools',
#  'Active Life',
#  'Boot Camps',
#  'Trainers',
#  'Fitness & Instruction',
#  'Gyms',
#  'Active Life',
#  'Parks',
#  'Local Flavor',
#  'Food Court',
#  'Restaurants',
#  'Barbeque',
#  'Music Venues',
#  'Lounges',
#  'Dive Bars',
#  'Bars',
#  'Nightlife',
#  'Piano Bars',
#  'Arts & Entertainment',
#  'Home Services',
#  'Shopping',
#  'Home Decor',
#  'Shades & Blinds',
#  'Interior Design',
#  'Building Supplies',
#  'Home & Garden',
#  'Canadian (New)',
#  'Restaurants',
#  'Breakfast & Brunch',
#  'Pool & Hot Tub Service',
#  'Home Services',
#  'Landscape Architects',
#  'Active Life',
#  'Contractors',
#  'Swimming Pools',
#  'Landscaping',
#  'Italian',
#  'Restaurants',
#  'Sandwiches',
#  'Hot Dogs',
#  'Transportation',
#  'Event Planning & Services',
#  'Airlines',
#  'Hotels & Travel',
#  'Airport Shuttles',
#  'Limos',
#  'Party Bus Rentals',
#  'Public Transportation',
#  'Fashion',
#  "Men's Clothing",
#  'Shopping',
#  'Plus Size Fashion',
#  'Formal Wear',
#  'Shopping',
#  "Men's Clothing",
#  'Shoe Stores',
#  'Fashion',
#  "Women's Clothing",
#  'Mortgage Brokers',
#  'Financial Services',
#  'Mortgage Lenders',
#  'Real Estate',
#  'Home Services',
#  'Hair Removal',
#  'Beauty & Spas',
#  'Waxing',
#  'Nail Salons',
#  'Auto Repair',
#  'Gas Stations',
#  'Automotive',
#  'Arts & Entertainment',
#  'Yelp Events',
#  'Festivals',
#  'Local Flavor',
#  'Restaurants',
#  'Pizza',
#  'Shopping',
#  'Grocery',
#  'Florists',
#  'Flowers & Gifts',
#  'Bakeries',
#  'Convenience Stores',
#  'Food',
#  'Active Life',
#  'Sporting Goods',
#  'Karate',
#  'Education',
#  'Shopping',
#  'Martial Arts',
#  'Specialty Schools',
#  'Trainers',
#  'Fitness & Instruction',
#  'Pet Services',
#  'Pet Sitting',
#  'Dog Walkers',
#  'Pets',
#  'Fashion',
#  'Shoe Stores',
#  'Shopping',
#  'Chicken Wings',
#  'Restaurants',
#  'Fast Food',
#  'Shopping',
#  'Sporting Goods',
#  "Women's Clothing",
#  "Men's Clothing",
#  'Sports Wear',
#  'Fashion',
#  'Cosmetic Dentists',
#  'Dentists',
#  'Orthodontists',
#  'Health & Medical',
#  'General Dentistry',
#  'Jewelry',
#  'Arts & Crafts',
#  'Shopping',
#  'Pets',
#  'Veterinarians',
#  'Pet Services',
#  'Automotive',
#  'Auto Parts & Supplies',
#  'Food',
#  'Donuts',
#  'Coffee & Tea',
#  'Shopping',
#  'Sporting Goods',
#  'Restaurants',
#  'Sandwiches',
#  'Delis',
#  'Flooring',
#  'Carpeting',
#  'Carpet Installation',
#  'Home Services',
#  'Italian',
#  'Restaurants',
#  'Pizza',
#  'Education',
#  'Health & Medical',
#  'Beauty & Spas',
#  'Massage',
#  'Physical Therapy',
#  'Massage Therapy',
#  'Beauty & Spas',
#  'Hair Salons',
#  'Massage',
#  'Beauty & Spas',
#  'Real Estate Services',
#  'Real Estate',
#  'Home Services',
#  'Property Management',
#  'Real Estate Agents',
#  'Chinese',
#  'Restaurants',
#  'Dim Sum',
#  'Restaurants',
#  'Fast Food',
#  'Mexican',
#  'Restaurants',
#  'Nightlife',
#  'Bars',
#  'Fast Food',
#  'Restaurants',
#  'Chinese',
#  'Food',
#  'Caterers',
#  'Restaurants',
#  'Fast Food',
#  'French',
#  'Event Planning & Services',
#  'Food Delivery Services',
#  'Sushi Bars',
#  'Restaurants',
#  'Japanese',
#  'Asian Fusion',
#  'Vietnamese',
#  'Fast Food',
#  'Restaurants',
#  'Burgers',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Motorcycle Dealers',
#  'Automotive',
#  'Food',
#  'Ice Cream & Frozen Yogurt',
#  'Auto Parts & Supplies',
#  'Automotive',
#  'Fruits & Veggies',
#  'Shopping',
#  'Specialty Food',
#  'Flowers & Gifts',
#  'Food',
#  'Florists',
#  'Preschools',
#  'Child Care & Day Care',
#  'Local Services',
#  'Education',
#  'Elementary Schools',
#  'Home Services',
#  'Real Estate',
#  'Vietnamese',
#  'Restaurants',
#  'Arts & Entertainment',
#  'American (Traditional)',
#  'Sushi Bars',
#  'Nightlife',
#  'Restaurants',
#  'Music Venues',
#  'Fashion',
#  'Clothing Rental',
#  'Uniforms',
#  'Building Supplies',
#  'Home Services',
#  'Shopping',
#  'Beer',
#  'Wine & Spirits',
#  ...]

# %%
categories_series=pd.Series(categories_list2)

# %%
categories_series.value_counts().head(20).plot(kind='bar')

# %%
business_df['city-state']=business_df['city']+'-'+business_df['state']

# %%
business_df[city]
